# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dt=pd.read_csv(r"C:\Users\Lenovo-Pc\Match.csv")

# %%
dt.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %%
dt.tail()
# Out:
#      Match_SK  match_id                Team1                        Team2  \
# 632       632   1082646     Delhi Daredevils  Royal Challengers Bangalore
# 633       633   1082647       Mumbai Indians      Rising Pune Supergiants
# 634       634   1082648  Sunrisers Hyderabad        Kolkata Knight Riders
# 635       635   1082649       Mumbai Indians        Kolkata Knight Riders
# 636       636   1082650       Mumbai Indians      Rising Pune Supergiants
#
#     match_date  Season_Year                                Venue_Name  \
# 632  5/14/2017         2017                          Feroz Shah Kotla
# 633  5/16/2017         2017                          Wankhede Stadium
# 634  5/17/2017         2017                     M Chinnaswamy Stadium
# 635  5/19/2017         2017                     M Chinnaswamy Stadium
# 636  5/21/2017         2017  Rajiv Gandhi International Stadium Uppal
#
#               City_Name Country_Name                  Toss_Winner  \
# ...

# %%
dt.columns
# Out:
# Index(['Match_SK', 'match_id', 'Team1', 'Team2', 'match_date', 'Season_Year',
#        'Venue_Name', 'City_Name', 'Country_Name', 'Toss_Winner',
#        'match_winner', 'Toss_Name', 'Win_Type', 'Outcome_Type', 'ManOfMach',
#        'Win_Margin', 'Country_id'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.pairplot(dt.iloc[:,:])
# Out:
# D:\anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
import statsmodels.formula.api as smf

# %%
mpatches.replace(dt,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9c7bf5638d11> in <module>
# ----> 1 matches.replace(dt,inplace=True)
#
# NameError: name 'matches' is not defined

# %%
df=pd.DataFrame(dt.groupby(['Season_Year','match_date'])['match_winner'].count())
df
# Out:
#                         match_winner
# Season_Year match_date
# 2008        05-01-2008             2
#             05-02-2008             1
#             05-03-2008             2
#             05-04-2008             2
#             05-05-2008             1
#             05-06-2008             1
#             05-07-2008             1
#             05-08-2008             2
#             05-09-2008             1
#             05-10-2008             1
#             05-11-2008             2
#             05-12-2008             1
#             06-01-2008             1
#             4/18/2008              1
#             4/19/2008              2
#             4/20/2008              2
#             4/21/2008              1
#             4/22/2008              1
#             4/23/2008              1
#             4/24/2008              1
#             4/25/2008              1
#             4/26/2008              2
#             4/27/2008              2
#             4/28/2008              1
# ...

# %%
x=dt[dt.City_Name=='Hyderabad']
x.ManOfMach.count()
# Out:
# 41

# %%
data=ManOfMach.values_counts()
data
